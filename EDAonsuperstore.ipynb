# %% [markdown]
# ## Title - EDA on Super Store

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the data set

# %%
df = pd.read_excel(r"C:\Users\india\My Python Files\Sample_-_Superstore.xls")

# %% [markdown]
# # Attributes

# %% [markdown]
# ## displaying five rows of the dataset

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#displaying the last five rows

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ## Dimensions of dataset

# %%
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# ## Statistical Summary of the dataset

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355648
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %% [markdown]
# ## Columns in dataset

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ## Number of unique values in the each column

# %%
df.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            6144
# Quantity           14
# Discount           12
# Profit           7545
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# * Duplicates
# * Structural Errors
# * Missing values
# * Type Casting
# * Outliers

# %% [markdown]
# ## Checking null

# %%
df.isnull().sum()   #no null values
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ## Stuctural Errors

# %%
df['Quantity'].unique()
# Out:
# array([ 2,  3,  5,  7,  4,  6,  9,  1,  8, 14, 11, 13, 10, 12],
#       dtype=int64)

# %%
for i in df:
    print(i)
    print(df[i].dtypes)
    print(df[i].unique())
# Out:
# Row ID
# int64
# [   1    2    3 ... 9992 9993 9994]
# Order ID
# object
# ['CA-2016-152156' 'CA-2016-138688' 'US-2015-108966' ... 'CA-2014-110422'
#  'CA-2017-121258' 'CA-2017-119914']
# Order Date
# datetime64[ns]
# <DatetimeArray>
# ['2016-11-08 00:00:00', '2016-06-12 00:00:00', '2015-10-11 00:00:00',
#  '2014-06-09 00:00:00', '2017-04-15 00:00:00', '2016-12-05 00:00:00',
#  '2015-11-22 00:00:00', '2014-11-11 00:00:00', '2014-05-13 00:00:00',
#  '2014-08-27 00:00:00',
#  ...
#  '2016-10-11 00:00:00', '2014-06-18 00:00:00', '2017-02-28 00:00:00',
#  '2015-05-09 00:00:00', '2014-11-06 00:00:00', '2015-12-29 00:00:00',
#  '2014-04-03 00:00:00', '2016-06-03 00:00:00', '2015-04-12 00:00:00',
#  '2014-01-21 00:00:00']
# Length: 1237, dtype: datetime64[ns]
# Ship Date
# datetime64[ns]
# <DatetimeArray>
# ['2016-11-11 00:00:00', '2016-06-16 00:00:00', '2015-10-18 00:00:00',
#  '2014-06-14 00:00:00', '2017-04-20 00:00:00', '2016-12-10 00:00:00',
# ...

# %% [markdown]
# ## Type of the Features or columns

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %% [markdown]
# ## Counts the number of the data in the column

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: count, Length: 531, dtype: int64

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States    9994
# Name: count, dtype: int64

# %%
df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
df['State'].value_counts()
# Out:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %% [markdown]
# ## Duplicated values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Dropping unwanted columns

# %%
df.drop(['Row ID','Order ID', 'Postal Code'], axis = 1,  inplace = True )

# %% [markdown]
# ## Outliers

# %% [markdown]
# #### Satistical method

# %%
D = df.select_dtypes(exclude=["object", 'datetime64[ns]'])

# %%
for i in D.columns:
    q1 = D[i].quantile(0.25)
    q3 = D[i].quantile(0.75)
    IQR = q3 - q1
    lower = q1 -(1.5 * IQR)
    upper = q3 +(1.5 * IQR)
    print(f"{i} lower limit is {lower} ")
    print(f'{i} upper limit is {upper} ')
# Out:
# Sales lower limit is -271.71000000000004
# Sales upper limit is 498.93
# Quantity lower limit is -2.5
# Quantity upper limit is 9.5
# Discount lower limit is -0.30000000000000004
# Discount upper limit is 0.5
# Profit lower limit is -39.724124999999994
# Profit upper limit is 70.81687499999998

# %%
df.plot(kind = 'box', subplots = True, layout = (3,2), figsize = (8,6))
plt.show()

# %% [markdown]
# ## Univariable Analysis

# %% [markdown]
# Numerical - Hist, Box, Density

# %%
plt.style.use('classic')

# %% [markdown]
# ## Histogram

# %%
# to find the distribution

# %%
df['Discount'].plot(kind = 'hist', figsize = (5,3))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Profit'].plot(kind = 'hist', figsize = (5,3), color = 'green')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Sales'].plot(kind = 'hist', figsize = (5,3), color = 'darkgreen')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Quantity'].plot(kind = 'hist', figsize = (5,3), color = 'teal')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Box plot

# %%
# to find the outliers

# %%
df['Sales'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['Profit'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['Quantity'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['Discount'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ## Density Plot

# %%
#to find the distribution

# %%
df['Sales'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Discount'].mean(),df['Discount'].median()
# Out:
# (0.1561883318322826, 0.2)

# %%
df['Discount'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Quantity'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Profit'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ##### Summary

# %% [markdown]
# * It is not distributed normally.
# * There are outliers in the dataset
# * no density plot is bell shaped

# %% [markdown]
# ## Categorical

# %% [markdown]
# count, bar, pie

# %% [markdown]
# #### Count plot using seaborn

# %%
sns.countplot(data = df,x = 'Category' , color = 'pink', orient = 'h')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot(data = df,x = 'Ship Mode' , color = 'violet', orient = 'h')
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
# ## Bar

# %%
df['State'].value_counts().plot(kind = 'barh', figsize = (9,7), color = ['pink', 'violet'])
# Out:
# <Axes: ylabel='State'>

# %%
df['Region'].value_counts().plot(kind = 'bar', color = [ '#FF7043','#FFA726', '#FFCA28','#FFEE58'])
# Out:
# <Axes: xlabel='Region'>

# %%
df['Category'].value_counts().plot(kind = 'bar',
                                   title = "Products Category",
                                   color = ['#388E3C', '#66BB6A', '#C8E6C9'],
                                  )
# Out:
# <Axes: title={'center': 'Products Category'}, xlabel='Category'>

# %%
df['Sub-Category'].value_counts().plot(kind = 'barh', color = ['skyblue', 'blue'], figsize = (15,7))
# Out:
# <Axes: ylabel='Sub-Category'>

# %% [markdown]
# ## Pie

# %%
df['Sub-Category'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', figsize = (5,5))
# Out:
# <Axes: ylabel='count'>

# %%
df['Ship Mode'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%'
                                   )
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### summary

# %% [markdown]
# * California state purchased maximum products.
# * Wyoming state has the least purchased products.
# * Papers and Binders are the maximum sold products.
# * Mostly purchased category is for Office Supplies
# * Mostly choosed Ship Mode is Standard Class.

# %% [markdown]
# ## Categorical and Categorical

# %%
## crosstab, count plot, stacked

# %%
pd.crosstab(df['Country'], df['State'])
# Out:
# State          Alabama  Arizona  Arkansas  California  Colorado  Connecticut  \
# Country
# United States       61      224        60        2001       182           82
#
# State          Delaware  District of Columbia  Florida  Georgia  ...  \
# Country                                                          ...
# United States        96                    10      383      184  ...
#
# State          South Dakota  Tennessee  Texas  Utah  Vermont  Virginia  \
# Country
# United States            12        183    985    53       11       224
#
# State          Washington  West Virginia  Wisconsin  Wyoming
# Country
# United States         506              4        110        1
#
# [1 rows x 49 columns]

# %%
pd.crosstab(df['State'], df['Region'])
# Out:
# Region                Central  East  South  West
# State
# Alabama                     0     0     61     0
# Arizona                     0     0      0   224
# Arkansas                    0     0     60     0
# California                  0     0      0  2001
# Colorado                    0     0      0   182
# Connecticut                 0    82      0     0
# Delaware                    0    96      0     0
# District of Columbia        0    10      0     0
# Florida                     0     0    383     0
# Georgia                     0     0    184     0
# Idaho                       0     0      0    21
# Illinois                  492     0      0     0
# Indiana                   149     0      0     0
# Iowa                       30     0      0     0
# Kansas                     24     0      0     0
# Kentucky                    0     0    139     0
# Louisiana                   0     0     42     0
# Maine                       0     8      0     0
# ...

# %%
pd.crosstab(df['Segment'], df['City'])
# Out:
# City         Aberdeen  Abilene  Akron  Albuquerque  Alexandria  Allen  \
# Segment
# Consumer            1        1     13            4           3      4
# Corporate           0        0      6            4           6      0
# Home Office         0        0      2            6           7      0
#
# City         Allentown  Altoona  Amarillo  Anaheim  ...  Wilmington  Wilson  \
# Segment                                             ...
# Consumer             2        0         8       16  ...          24       2
# Corporate            0        2         2       11  ...           9       3
# Home Office          5        0         0        0  ...           3       1
#
# City         Woodbury  Woodland  Woodstock  Woonsocket  Yonkers  York  \
# Segment
# Consumer            0         1          3           1       13     0
# Corporate           3         2          1           3        0     5
# Home Office         0         0          1           0        2     0
#
# ...

# %%
sns.countplot(data = df, x = 'Category', hue = 'Sub-Category',width=0.5)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Country', hue = 'State',width=1, legend = False)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Country', hue = 'Region',width=1)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sns.countplot(data = df, x = 'State', hue = 'Region',width=1)
# Out:
# <Axes: xlabel='State', ylabel='count'>

# %% [markdown]
# * In United States, California has highest of 2001 sales
# * wyoming is the least has only 1 sale.
# * Sales of office supplies are more which are paper,binder,art etc
# * Sales in west are more.

# %% [markdown]
# ## Categorical & Numerical

# %% [markdown]
# Group By, Pivot, Line chart

# %%
#The average number of sales in each state

# %%
df.groupby(by = "State")['Sales'].mean()
# Out:
# State
# Alabama                  319.846557
# Arizona                  157.508933
# Arkansas                 194.635500
# California               228.729451
# Colorado                 176.418231
# Connecticut              163.223866
# Delaware                 285.948635
# District of Columbia     286.502000
# Florida                  233.612815
# Georgia                  266.825217
# Idaho                    208.689810
# Illinois                 162.939230
# Indiana                  359.431946
# Iowa                     152.658667
# Kansas                   121.429583
# Kentucky                 263.250000
# Louisiana                219.453095
# Maine                    158.816250
# Maryland                 225.766886
# Massachusetts            212.106919
# Michigan                 299.096525
# Minnesota                335.541011
# Mississippi              203.232830
# Missouri                 336.441667
# Montana                  372.623467
# Nebraska                 196.445526
# ...

# %%
#the average sale in united sales

# %%
df.groupby(by = "Country")['Sales'].mean()
# Out:
# Country
# United States    229.858001
# Name: Sales, dtype: float64

# %%
# the average number of sales in each region

# %%
df.groupby(by = "Region")['Sales'].mean()
# Out:
# Region
# Central    215.772661
# East       238.336110
# South      241.803645
# West       226.493233
# Name: Sales, dtype: float64

# %%
df.groupby(by = "Category")['Sales'].max()
# Out:
# Category
# Furniture           4416.174
# Office Supplies     9892.740
# Technology         22638.480
# Name: Sales, dtype: float64

# %% [markdown]
# ## Line chart

# %%
df['Sales'].plot(kind = 'line')
# Out:
# <Axes: >

# %%
df['Profit'].plot(kind = 'line')
# Out:
# <Axes: >

# %% [markdown]
# ## MultiVariate Analysis

# %%
df.corr(numeric_only = True)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# ## Scatter Plot

# %%
df.plot("Sales", 'Profit', kind = 'scatter')
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
sns.heatmap(df.corr(numeric_only = True), annot = True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %% [markdown]
# ##### summary

# %% [markdown]
# * the correlation between profit and discount is negative.
# * the correlation between profit and sales is moderate.
# * there are no positively correlation in the data
